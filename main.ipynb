# %%
import pandas as pd
import numpy as np

# %%
champs_df = pd.read_csv("Set3Champions.csv")
items_df = pd.read_csv("TFT_Item_CurrentVersion.csv")

# %%
champs_df.head()
# Out:
#         name  cost  health  defense  magic_resist  attack  attack_range  \
# 0  gangplank     5    1000       30            20      60             1
# 1     graves     1     650       35            20      55             1
# 2      neeko     3     800       35            20      50             2
# 3     darius     2     750       35            20      60             1
# 4      rakan     2     600       35            20      45             2
#
#    attack_speed  dps            skill_name skill_cost         origin  \
# 0          1.00   60        Orbital Strike    100/175   Space Pirate
# 1          0.55   30         Smoke Grenade      50/80   Space Pirate
# 2          0.65   33           Pop Blossom     75/150  Star Guardian
# 3          0.65   39  Dreadnova Guillotine       0/60   Space Pirate
# 4          0.70   32        Grand Entrance     50/100      Celestial
#
#                             class
# 0  ['Mercenary', 'Demolitionist']
# 1                     ['Blaster']
# ...

# %%
items_df.head()
# Out:
#    id                  name
# 0   1            B.F. Sword
# 1   2           Recurve Bow
# 2   3  Needlessly Large Rod
# 3   4   Tear of the Goddess
# 4   5            Chain Vest
